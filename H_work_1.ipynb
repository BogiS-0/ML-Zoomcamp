# %%
import numpy as np
np.__version__
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
import os
os.getcwd()
os.chdir('anaconda3\envs\ml-zoomcamp\data') #change dir

# %%
df = pd.read_csv('data.csv')
df.head(n=10)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
pd.options.display.float_format = '{:20,.2f}'.format #non-scientific view
df.groupby('Make').MSRP.mean() #Question 3
# Out:
# Make
# Acura                      34,887.59
# Alfa Romeo                 61,600.00
# Aston Martin              197,910.38
# Audi                       53,452.11
# BMW                        61,546.76
# Bentley                   247,169.32
# Bugatti                 1,757,223.67
# Buick                      28,206.61
# Cadillac                   56,231.32
# Chevrolet                  28,350.39
# Chrysler                   26,722.96
# Dodge                      22,390.06
# FIAT                       22,670.24
# Ferrari                   238,218.84
# Ford                       27,399.27
# GMC                        30,493.30
# Genesis                    46,616.67
# HUMMER                     36,464.41
# Honda                      26,674.34
# Hyundai                    24,597.04
# Infiniti                   42,394.21
# Kia                        25,310.17
# Lamborghini               331,567.31
# Land Rover                 67,823.22
# Lexus                      47,549.07
# ...

# %%
mean_hp_before = df['Engine HP'].mean()  #Question 5
print(round(mean_hp_before))
df.fillna(mean_hp_before)
mean_hp_after = df['Engine HP'].mean()
print(round(mean_hp_after))

#df[df['Year'] >= 2015].isnull().sum() #Question 4
#df.isnull().sum()
# Out:
# 249
# 249

# %%
df2 = df[df['Make'] == 'Rolls-Royce']   #Questions 6
x = df2[['Engine HP', 'Engine Cylinders', 'highway MPG']].drop_duplicates().to_numpy()
xtx = x.T.dot(x)
print(xtx)
inv = np.linalg.inv(xtx)
print(inv.sum())
#df[['Engine HP', 'Engine Cylinders', 'highway MPG']]
# Out:
# [[325.   8.  15.]
#  [563.  12.  19.]
#  [563.  12.  21.]
#  [563.  12.  20.]
#  [322.  12.  15.]
#  [453.  12.  19.]
#  [624.  12.  21.]]
# [[1.754801e+06 3.965600e+04 6.519600e+04]
#  [3.965600e+04 9.280000e+02 1.500000e+03]
#  [6.519600e+04 1.500000e+03 2.454000e+03]]
# 0.03221232067748617

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300]) #Questions 7
w = inv.dot(x.T).dot(y)
print(w)
# Out:
# [ 0.19989598 31.02612262 31.65378877]
